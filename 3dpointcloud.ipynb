# %%
import numpy as np
import matplotlib.pyplot as plt
import os
# from mpl_toolkits.mplot3d import Axes3D


data = np.loadtxt("./myfed_normal_save/param04-20--19-31-44.dat")
points = []

for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        points.append([i, j, abs(data[i][j])])

x=[point[0] for point in points]
y=[point[1] for point in points]
z=[point[2] for point in points]

fig=plt.figure(dpi=120)
ax=fig.add_subplot(111,projection='3d')
plt.title('point cloud')
ax.scatter(x,y,z,c='b',marker='.',s=2,linewidth=0,alpha=1,cmap='spectral')

#ax.set_facecolor((0,0,0))
ax.axis('auto')
# ax.xaxis.set_visible(False)
# ax.yaxis.set_visible(False)
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
plt.show()

# %%
import pandas as pd

# %%
dt = {'dimensions': [3], 'Number of points': [len(points)], 'Points: x': x, 'Points: y': y, 'Points: z': z}
df = pd.DataFrame(dict([(k, pd.Series(v)) for k, v in dt.items()]))
df.to_csv('./myfed_normal_save/param04-20--19-31-44.csv', index=False)
